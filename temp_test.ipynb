# %%
from dictionary_gen_functions import compare_reward_time_dml_no_time

metrics = compare_reward_time_dml_no_time(
    theta_bound=20,
    csv_index=8,
    dimension=5,
    data_points=14000,
    test_data_points=1000,
    a_val=1.0,
    k_fold=2,
    a_dist="nodist",
    a_dist_k=None
)

# %%
metrics ##(k_fold =4)
# Out:
# {'logistic': {'distance': np.float64(9.332227630341597),
#   'accuracy': np.float64(0.974)},
#  'dml-time-separate': {'distance': np.float64(2.683851444327625),
#   'accuracy': np.float64(0.974)},
#  'dml-non-ortho-time-separate': {'distance': np.float64(4.100910168058757),
#   'accuracy': np.float64(0.974)},
#  'dml-time-separate-cross-val': {'distance': np.float64(0.7315488622573505),
#   'accuracy': np.float64(0.971)},
#  'dml-non-ortho-time-separate-cross-val': {'distance': np.float64(1.6706609522640494),
#   'accuracy': np.float64(0.973)},
#  'dml-time-separate-reuse': {'distance': np.float64(1.394913207867921),
#   'accuracy': np.float64(0.973)},
#  'dml-non-ortho-time-separate-reuse': {'distance': np.float64(2.8222324248120567),
#   'accuracy': np.float64(0.978)}}

# %%
metrics ##(for k =2 )
# Out:
# {'logistic': {'distance': np.float64(9.332227630341597),
#   'accuracy': np.float64(0.974)},
#  'dml-time-separate': {'distance': np.float64(3.855553626283873),
#   'accuracy': np.float64(0.973)},
#  'dml-non-ortho-time-separate': {'distance': np.float64(6.799457760965602),
#   'accuracy': np.float64(0.974)},
#  'dml-time-separate-cross-val': {'distance': np.float64(3.6661454693040496),
#   'accuracy': np.float64(0.974)},
#  'dml-non-ortho-time-separate-cross-val': {'distance': np.float64(6.676208252633488),
#   'accuracy': np.float64(0.972)},
#  'dml-time-separate-reuse': {'distance': np.float64(1.394913207867921),
#   'accuracy': np.float64(0.973)},
#  'dml-non-ortho-time-separate-reuse': {'distance': np.float64(2.8222324248120567),
#   'accuracy': np.float64(0.978)}}

# %% [markdown]
# # Dim 20 bound 20

# %%
metrics
# Out:
# {'logistic': {'distance': np.float64(7.116137504095539),
#   'accuracy': np.float64(0.945)},
#  'dml-time-separate': {'distance': np.float64(1.6800653343936105),
#   'accuracy': np.float64(0.945)},
#  'dml-non-ortho-time-separate': {'distance': np.float64(2.8886030595532337),
#   'accuracy': np.float64(0.943)},
#  'dml-time-separate-cross-val': {'distance': np.float64(0.41045421168338453),
#   'accuracy': np.float64(0.946)},
#  'dml-non-ortho-time-separate-cross-val': {'distance': np.float64(0.7575653037133194),
#   'accuracy': np.float64(0.943)},
#  'dml-time-separate-reuse': {'distance': np.float64(0.9185535099728043),
#   'accuracy': np.float64(0.947)},
#  'dml-non-ortho-time-separate-reuse': {'distance': np.float64(2.3643816624473883),
#   'accuracy': np.float64(0.948)}}

# %%
metrics ## with k_fold = 2
# Out:
# {'logistic': {'distance': np.float64(7.116137504095539),
#   'accuracy': np.float64(0.945)},
#  'dml-time-separate': {'distance': np.float64(0.24917210128625852),
#   'accuracy': np.float64(0.943)},
#  'dml-non-ortho-time-separate': {'distance': np.float64(0.3438736312852415),
#   'accuracy': np.float64(0.943)},
#  'dml-time-separate-cross-val': {'distance': np.float64(1.7710291371118068),
#   'accuracy': np.float64(0.946)},
#  'dml-non-ortho-time-separate-cross-val': {'distance': np.float64(3.2768143126051106),
#   'accuracy': np.float64(0.945)},
#  'dml-time-separate-reuse': {'distance': np.float64(0.9185535099728043),
#   'accuracy': np.float64(0.947)},
#  'dml-non-ortho-time-separate-reuse': {'distance': np.float64(2.3643816624473883),
#   'accuracy': np.float64(0.948)}}

# %%
import pickle
with open("data_gen/dictionary_diff_diff_data_crossfit_reuse_kfold4.pkl", "rb") as f:
    data = pickle.load(f)

print(data.keys())
# Out:
# dict_keys([(1, 0, 5, 1000, 1.0), (1, 1, 5, 1000, 1.0), (1, 2, 5, 1000, 1.0), (1, 3, 5, 1000, 1.0), (1, 4, 5, 1000, 1.0), (1, 5, 5, 1000, 1.0), (1, 6, 5, 1000, 1.0), (1, 7, 5, 1000, 1.0), (1, 8, 5, 1000, 1.0), (1, 9, 5, 1000, 1.0), (1, 0, 5, 2000, 1.0), (1, 1, 5, 2000, 1.0), (1, 2, 5, 2000, 1.0), (1, 3, 5, 2000, 1.0), (1, 4, 5, 2000, 1.0), (1, 5, 5, 2000, 1.0), (1, 6, 5, 2000, 1.0), (1, 7, 5, 2000, 1.0), (1, 8, 5, 2000, 1.0), (1, 9, 5, 2000, 1.0), (1, 0, 5, 5000, 1.0), (1, 1, 5, 5000, 1.0), (1, 2, 5, 5000, 1.0), (1, 3, 5, 5000, 1.0), (1, 4, 5, 5000, 1.0), (1, 5, 5, 5000, 1.0), (1, 6, 5, 5000, 1.0), (1, 7, 5, 5000, 1.0), (1, 8, 5, 5000, 1.0), (1, 9, 5, 5000, 1.0), (1, 0, 5, 8000, 1.0), (1, 1, 5, 8000, 1.0), (1, 2, 5, 8000, 1.0), (1, 3, 5, 8000, 1.0), (1, 4, 5, 8000, 1.0), (1, 5, 5, 8000, 1.0), (1, 6, 5, 8000, 1.0), (1, 7, 5, 8000, 1.0), (1, 8, 5, 8000, 1.0), (1, 9, 5, 8000, 1.0), (1, 0, 5, 10000, 1.0), (1, 1, 5, 10000, 1.0), (1, 2, 5, 10000, 1.0), (1, 3, 5, 10000, 1.0), (1, 4, 5, 10000
# ...
